# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Udacity_AZDIAS_Subset.csv', sep = ';')
df_info = pd.read_csv('AZDIAS_Feature_Summary.csv', sep = ';')

# %%
df_info.head()
# Out:
#               attribute information_level         type missing_or_unknown
# 0              AGER_TYP            person  categorical             [-1,0]
# 1  ALTERSKATEGORIE_GROB            person      ordinal           [-1,0,9]
# 2             ANREDE_KZ            person  categorical             [-1,0]
# 3         CJT_GESAMTTYP            person  categorical                [0]
# 4     FINANZ_MINIMALIST            person      ordinal               [-1]

# %%
df_info.type.unique()
# Out:
# array(['categorical', 'ordinal', 'numeric', 'mixed', 'interval'],
#       dtype=object)

# %%
df.head()
# Out:
#    AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0        -1                     2          1            2.0
# 1        -1                     1          2            5.0
# 2        -1                     3          2            3.0
# 3         2                     4          2            2.0
# 4        -1                     3          1            5.0
#
#    FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                  3              4                 3               5
# 1                  1              5                 2               5
# 2                  1              4                 1               2
# 3                  4              2                 5               2
# 4                  4              3                 4               1
#
#    FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER    ...     PLZ8_ANTG1  PLZ8_ANTG2  \
# 0                      5                 3    ...            NaN         NaN
# ...

# %%
categorical_info = df_info[df_info.type == 'categorical']
categorical_features = categorical_info.attribute # series

# %%
categorical_df = df.loc[:, categorical_features]

# %%
categorical_df.head()
# Out:
#    AGER_TYP  ANREDE_KZ  CJT_GESAMTTYP  FINANZTYP  GFK_URLAUBERTYP  \
# 0        -1          1            2.0          4             10.0
# 1        -1          2            5.0          1             10.0
# 2        -1          2            3.0          1             10.0
# 3         2          2            2.0          6              1.0
# 4        -1          1            5.0          5              5.0
#
#    GREEN_AVANTGARDE  LP_FAMILIE_FEIN  LP_FAMILIE_GROB  LP_STATUS_FEIN  \
# 0                 0              2.0              2.0             1.0
# 1                 0              5.0              3.0             2.0
# 2                 1              1.0              1.0             3.0
# 3                 0              0.0              0.0             9.0
# 4                 0             10.0              5.0             3.0
#
#    LP_STATUS_GROB      ...        SHOPPER_TYP  SOHO_KZ  TITEL_KZ  VERS_TYP  \
# ...

# %%
# counting unique values per column items
unique_values_per_column_count = categorical_df.nunique(axis=0, dropna = True) # series

# %%
# filtering no binary categorical features
no_binary_filter = unique_column_items_count > 2 # boolean series

# %%
# no binary features
no_binary_features = unique_values_per_column_count[no_binary_filter].index.tolist()

# %%
# no binary dataframe
no_binary_df = categorical_df[no_binary_features]

# %%
no_binary_df.head()
# Out:
#    AGER_TYP  CJT_GESAMTTYP  FINANZTYP  GFK_URLAUBERTYP  LP_FAMILIE_FEIN  \
# 0        -1            2.0          4             10.0              2.0
# 1        -1            5.0          1             10.0              5.0
# 2        -1            3.0          1             10.0              1.0
# 3         2            2.0          6              1.0              0.0
# 4        -1            5.0          5              5.0             10.0
#
#    LP_FAMILIE_GROB  LP_STATUS_FEIN  LP_STATUS_GROB  NATIONALITAET_KZ  \
# 0              2.0             1.0             1.0                 0
# 1              3.0             2.0             1.0                 1
# 2              1.0             3.0             2.0                 1
# 3              0.0             9.0             4.0                 1
# 4              5.0             3.0             2.0                 1
#
#    SHOPPER_TYP  TITEL_KZ  VERS_TYP  ZABEOTYP  KK_KUNDENTYP  GEBAEUDETYP  \
# ...

# %%
# binary dataframe
binary_df = categorical_df.drop(no_binary_features, axis=1)

# %%
binary_df.head()
# Out:
#    ANREDE_KZ  GREEN_AVANTGARDE  SOHO_KZ OST_WEST_KZ
# 0          1                 0      NaN         NaN
# 1          2                 0      1.0           W
# 2          2                 1      0.0           W
# 3          2                 0      0.0           W
# 4          1                 0      0.0           W
